# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import diffusers
import transformers
import sys
import os
import shutil
import time
import subprocess
import torch
import matplotlib.pyplot as plt
import numpy as np
import diffusers
from PIL import Image

if torch.cuda.is_available():
    device_name = torch.device("cuda")
    torch_dtype = torch.float16
else:
    device_name = torch.device("cpu")
    torch_dtype = torch.float32

# %%
# pipe = diffusers.StableDiffusionPipeline.from_single_file("models/OhmwMan.ckpt")

# pipe.save_pretrained("OhmwMan")

# %%
# pipe = diffusers.StableDiffusionPipeline.from_single_file("realisticVisionV60B1_v51VAE.safetensors")

# pipe.save_pretrained("converted_realisticVisionV60B1_v51VAE")

model_path = "converted_realisticVisionV60B1_v51VAE"

# %%
dreambooth_filename = "train_dreambooth.py"
img_folder_path = "images"
output_dir = "ohmwWithPPL"
class_prompt = "ohmw man"
IMG_SIZE = 512
TRAINING_STEPS = 2500
class_data_dir = "class_data_dir"


process = [
    "accelerate", 
    "launch",
    f"{dreambooth_filename}",
    "--train_text_encoder",
    "--allow_tf32",
    f"--pretrained_model_name_or_path={model_path}",
    f"--instance_data_dir={img_folder_path}",
    f"--output_dir={output_dir}",
    f"--instance_prompt='{class_prompt}'",
    f"--resolution={IMG_SIZE}",
    f"--train_batch_size=1",
    f"--gradient_accumulation_steps=1",
    "--gradient_checkpointing",
    f"--learning_rate=1e-6",
    f"--lr_scheduler=constant",
    f"--lr_warmup_steps=0",
    f"--max_train_steps={TRAINING_STEPS}",
    "--checkpointing_steps=500",
    "--mixed_precision=bf16",
]

# Extend process configuration
process.extend(
    [
        f"--with_prior_preservation",
        f"--prior_generation_precision=bf16",
        f"--sample_batch_size=1",
        f"--class_prompt='a man'",
        f"--class_data_dir={class_data_dir}",
    ]
)

process.extend(
    [
        f"--report_to=wandb",
        f'--validation_prompt="wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed"',
        f"--num_validation_images=3",
        f"--validation_steps=250",
        f"--seed=42",
    ]
)

# Run the process
subprocess.run(process, check=True)
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2024-02-20 00:12:17.715891: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-20 00:12:17.715976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-20 00:12:17.883472: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-20 00:12:18.227244: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-20 00:12:20.020808: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 02/20/2024 00:12:23 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: bf16
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'variance_type'} was not found in config. Values will be initialized to default values.
# wandb: Currently logged in as: austinfujimoriaustinfujimori. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.3
# wandb: Run data is saved locally in /home/ubuntu/wandb/run-20240220_001244-cp5ewl9t
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run auspicious-dog-31
# wandb: ⭐️ View project at https://wandb.ai/austinfujimoriaustinfujimori/dreambooth
# wandb: 🚀 View run at https://wandb.ai/austinfujimoriaustinfujimori/dreambooth/runs/cp5ewl9t
# 02/20/2024 00:12:44 - INFO - __main__ - ***** Running training *****
# 02/20/2024 00:12:44 - INFO - __main__ -   Num examples = 100
# 02/20/2024 00:12:44 - INFO - __main__ -   Num batches each epoch = 100
# 02/20/2024 00:12:44 - INFO - __main__ -   Num Epochs = 25
# 02/20/2024 00:12:44 - INFO - __main__ -   Instantaneous batch size per device = 1
# 02/20/2024 00:12:44 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 02/20/2024 00:12:44 - INFO - __main__ -   Gradient Accumulation steps = 1
# 02/20/2024 00:12:44 - INFO - __main__ -   Total optimization steps = 2500
# Steps:   0%|          | 0/2500 [00:00<?, ?it/s]/home/ubuntu/handrefiner_env/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# Steps:  10%|█         | 250/2500 [02:38<23:42,  1.58it/s, loss=0.24, lr=9e-7]02/20/2024 00:15:22 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 865.59it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# /home/ubuntu/handrefiner_env/lib/python3.10/site-packages/torch/utils/checkpoint.py:61: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# Steps:  20%|██        | 500/2500 [05:18<20:13,  1.65it/s, loss=0.0213, lr=8e-7]02/20/2024 00:18:03 - INFO - accelerate.accelerator - Saving current state to ohmwWithPPL/checkpoint-500
# Configuration saved in ohmwWithPPL/checkpoint-500/unet/config.json
# Model weights saved in ohmwWithPPL/checkpoint-500/unet/diffusion_pytorch_model.safetensors
# 02/20/2024 00:18:33 - INFO - accelerate.checkpointing - Optimizer state saved in ohmwWithPPL/checkpoint-500/optimizer.bin
# 02/20/2024 00:18:33 - INFO - accelerate.checkpointing - Scheduler state saved in ohmwWithPPL/checkpoint-500/scheduler.bin
# 02/20/2024 00:18:33 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in ohmwWithPPL/checkpoint-500/sampler.bin
# 02/20/2024 00:18:33 - INFO - accelerate.checkpointing - Random states saved in ohmwWithPPL/checkpoint-500/random_states_0.pkl
# 02/20/2024 00:18:33 - INFO - __main__ - Saved state to ohmwWithPPL/checkpoint-500
# 02/20/2024 00:18:33 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2924.90it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  30%|███       | 750/2500 [08:28<18:33,  1.57it/s, loss=0.433, lr=7e-7]02/20/2024 00:21:13 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2870.45it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  40%|████      | 1000/2500 [11:08<15:09,  1.65it/s, loss=0.303, lr=6e-7]02/20/2024 00:23:53 - INFO - accelerate.accelerator - Saving current state to ohmwWithPPL/checkpoint-1000
# Configuration saved in ohmwWithPPL/checkpoint-1000/unet/config.json
# Model weights saved in ohmwWithPPL/checkpoint-1000/unet/diffusion_pytorch_model.safetensors
# 02/20/2024 00:24:23 - INFO - accelerate.checkpointing - Optimizer state saved in ohmwWithPPL/checkpoint-1000/optimizer.bin
# 02/20/2024 00:24:23 - INFO - accelerate.checkpointing - Scheduler state saved in ohmwWithPPL/checkpoint-1000/scheduler.bin
# 02/20/2024 00:24:23 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in ohmwWithPPL/checkpoint-1000/sampler.bin
# 02/20/2024 00:24:23 - INFO - accelerate.checkpointing - Random states saved in ohmwWithPPL/checkpoint-1000/random_states_0.pkl
# 02/20/2024 00:24:23 - INFO - __main__ - Saved state to ohmwWithPPL/checkpoint-1000
# 02/20/2024 00:24:23 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2995.93it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  50%|█████     | 1250/2500 [14:18<12:46,  1.63it/s, loss=0.325, lr=5e-7]02/20/2024 00:27:03 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2948.75it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  60%|██████    | 1500/2500 [16:59<10:14,  1.63it/s, loss=0.103, lr=4e-7]02/20/2024 00:29:43 - INFO - accelerate.accelerator - Saving current state to ohmwWithPPL/checkpoint-1500
# Configuration saved in ohmwWithPPL/checkpoint-1500/unet/config.json
# Model weights saved in ohmwWithPPL/checkpoint-1500/unet/diffusion_pytorch_model.safetensors
# 02/20/2024 00:30:14 - INFO - accelerate.checkpointing - Optimizer state saved in ohmwWithPPL/checkpoint-1500/optimizer.bin
# 02/20/2024 00:30:14 - INFO - accelerate.checkpointing - Scheduler state saved in ohmwWithPPL/checkpoint-1500/scheduler.bin
# 02/20/2024 00:30:14 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in ohmwWithPPL/checkpoint-1500/sampler.bin
# 02/20/2024 00:30:14 - INFO - accelerate.checkpointing - Random states saved in ohmwWithPPL/checkpoint-1500/random_states_0.pkl
# 02/20/2024 00:30:14 - INFO - __main__ - Saved state to ohmwWithPPL/checkpoint-1500
# 02/20/2024 00:30:14 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2972.15it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  70%|███████   | 1750/2500 [20:09<07:40,  1.63it/s, loss=0.475, lr=3e-7]02/20/2024 00:32:54 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2860.27it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  80%|████████  | 2000/2500 [22:49<05:03,  1.65it/s, loss=1.05, lr=2e-7]02/20/2024 00:35:34 - INFO - accelerate.accelerator - Saving current state to ohmwWithPPL/checkpoint-2000
# Configuration saved in ohmwWithPPL/checkpoint-2000/unet/config.json
# Model weights saved in ohmwWithPPL/checkpoint-2000/unet/diffusion_pytorch_model.safetensors
# 02/20/2024 00:36:04 - INFO - accelerate.checkpointing - Optimizer state saved in ohmwWithPPL/checkpoint-2000/optimizer.bin
# 02/20/2024 00:36:04 - INFO - accelerate.checkpointing - Scheduler state saved in ohmwWithPPL/checkpoint-2000/scheduler.bin
# 02/20/2024 00:36:04 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in ohmwWithPPL/checkpoint-2000/sampler.bin
# 02/20/2024 00:36:04 - INFO - accelerate.checkpointing - Random states saved in ohmwWithPPL/checkpoint-2000/random_states_0.pkl
# 02/20/2024 00:36:04 - INFO - __main__ - Saved state to ohmwWithPPL/checkpoint-2000
# 02/20/2024 00:36:04 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 2840.51it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps:  90%|█████████ | 2250/2500 [25:59<02:33,  1.63it/s, loss=0.111, lr=1e-7]02/20/2024 00:38:44 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 3087.23it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps: 100%|██████████| 2500/2500 [28:39<00:00,  1.65it/s, loss=0.227, lr=4e-10]02/20/2024 00:41:24 - INFO - accelerate.accelerator - Saving current state to ohmwWithPPL/checkpoint-2500
# Configuration saved in ohmwWithPPL/checkpoint-2500/unet/config.json
# Model weights saved in ohmwWithPPL/checkpoint-2500/unet/diffusion_pytorch_model.safetensors
# 02/20/2024 00:41:54 - INFO - accelerate.checkpointing - Optimizer state saved in ohmwWithPPL/checkpoint-2500/optimizer.bin
# 02/20/2024 00:41:54 - INFO - accelerate.checkpointing - Scheduler state saved in ohmwWithPPL/checkpoint-2500/scheduler.bin
# 02/20/2024 00:41:54 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in ohmwWithPPL/checkpoint-2500/sampler.bin
# 02/20/2024 00:41:54 - INFO - accelerate.checkpointing - Random states saved in ohmwWithPPL/checkpoint-2500/random_states_0.pkl
# 02/20/2024 00:41:54 - INFO - __main__ - Saved state to ohmwWithPPL/checkpoint-2500
# 02/20/2024 00:41:54 - INFO - __main__ - Running validation...
#  Generating 3 images with prompt: "wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed".
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 3081.78it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# {'algorithm_type', 'use_karras_sigmas', 'use_lu_lambdas', 'lower_order_final', 'solver_type', 'solver_order', 'euler_at_final', 'final_sigmas_type', 'variance_type', 'lambda_min_clipped'} was not found in config. Values will be initialized to default values.
# Steps: 100%|██████████| 2500/2500 [29:15<00:00,  1.65it/s, loss=0.141, lr=0]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of converted_realisticVisionV60B1_v51VAE.
#
# Loading pipeline components...:  20%|██        | 1/5 [00:00<00:01,  3.96it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of converted_realisticVisionV60B1_v51VAE.
# Loaded vae as AutoencoderKL from `vae` subfolder of converted_realisticVisionV60B1_v51VAE.
#
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00,  8.62it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Configuration saved in ohmwWithPPL/vae/config.json
# Model weights saved in ohmwWithPPL/vae/diffusion_pytorch_model.safetensors
# Configuration saved in ohmwWithPPL/unet/config.json
# Model weights saved in ohmwWithPPL/unet/diffusion_pytorch_model.safetensors
# Configuration saved in ohmwWithPPL/scheduler/scheduler_config.json
# Configuration saved in ohmwWithPPL/model_index.json
# wandb:
# wandb:
# wandb: Run history:
# wandb: loss ▃▂▂▁▁▁▁▂▂▄▂▂▄▂▄▁▃▁█▃▅▁▁▁▄▁▂▃▄▂▂▄▁▃▂▂▃▁▂▁
# wandb:   lr ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:
# wandb: Run summary:
# wandb: loss 0.14113
# wandb:   lr 0.0
# wandb:
# wandb: 🚀 View run auspicious-dog-31 at: https://wandb.ai/austinfujimoriaustinfujimori/dreambooth/runs/cp5ewl9t
# wandb: Synced 5 W&B file(s), 30 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240220_001244-cp5ewl9t/logs
# /home/ubuntu/handrefiner_env/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:2171: UserWarning: Run (cp5ewl9t) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Steps: 100%|██████████| 2500/2500 [29:34<00:00,  1.41it/s, loss=0.141, lr=0]
# CompletedProcess(args=['accelerate', 'launch', 'train_dreambooth.py', '--train_text_encoder', '--allow_tf32', '--pretrained_model_name_or_path=converted_realisticVisionV60B1_v51VAE', '--instance_data_dir=images', '--output_dir=ohmwWithPPL', "--instance_prompt='ohmw man'", '--resolution=512', '--train_batch_size=1', '--gradient_accumulation_steps=1', '--gradient_checkpointing', '--learning_rate=1e-6', '--lr_scheduler=linear', '--lr_warmup_steps=0', '--max_train_steps=2500', '--checkpointing_steps=500', '--mixed_precision=bf16', '--with_prior_preservation', '--prior_generation_precision=bf16', '--sample_batch_size=1', "--class_prompt='a man'", '--class_data_dir=class_data_dir', '--report_to=wandb', '--validation_prompt="wide shot photo of ohmw man in a suit, professional, standing up, realistic, highly detailed"', '--num_validation_images=3', '--validation_steps=250', '--seed=42'], returncode=0)
